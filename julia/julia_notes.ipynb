# %% [markdown]
# # Notes on Julia
#
# ## Install Julia on a local Host
#
# Play-jupyter with Julia requires julia language to be installed
# - installed julia`sudo pamac install julia`
# - installed julia kernel through Julia "REPL":
#
# ```
#     julia> using Pkg
#     julia> Pkg.add("IJulia")
#     Installing known registries into `~/.julia`
#     ...
#     Building IJulia → `~/.julia/packages/IJulia/IDNmS/deps/build.log`
#     julia>
# ```
#
# - you may install julia kernel non-interactive
#   by executing `julia -e 'using Pkg; Pkg.add("IJulia")'`.
#   Don't know if this could be part of `pipfile`.
#
# ## Julia Cheatsheet
#
# [Julia Cheat Sheet for v1.0](https://juliadocs.github.io/Julia-Cheat-Sheet/)

# %%
Base.VERSION
# Out:
# v"1.9.4"

# %% [markdown]
# During my first look - and what I kept in mind - was a function to display all methods of a type(?) ...

# %%
methods(42)
# Out:
# # 0 methods for callable object

# %% [markdown]
# ... no, display all methods of function instead.
#
# Here is the documentation I found to recall:
# https://docs.julialang.org/en/v1/manual/methods/#Defining-Methods
#
# As an example, generic function '+' has got a lot of methods.

# %%
methods(+)
# Out:
# # 207 methods for generic function "+" from Base:
#    [1] +(x::T, y::T) where T<:Union{Int128, Int16, Int32, Int64, Int8, UInt128, UInt16, UInt32, UInt64, UInt8}
#      @ int.jl:87
#    [2] +(x::T, y::T) where T<:Union{Float16, Float32, Float64}
#      @ float.jl:408
#    [3] +(c::Union{UInt16, UInt32, UInt64, UInt8}, x::BigInt)
#      @ Base.GMP gmp.jl:539
#    [4] +(c::Union{Int16, Int32, Int64, Int8}, x::BigInt)
#      @ Base.GMP gmp.jl:545
#    [5] +(c::Union{UInt16, UInt32, UInt64, UInt8}, x::BigFloat)
#      @ Base.MPFR mpfr.jl:407
#    [6] +(c::Union{Int16, Int32, Int64, Int8}, x::BigFloat)
#      @ Base.MPFR mpfr.jl:415
#    [7] +(c::Union{Float16, Float32, Float64}, x::BigFloat)
#      @ Base.MPFR mpfr.jl:423
#    [8] +(x::Union{Dates.CompoundPeriod, Dates.Period})
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/periods.jl:342
#    [9] +(x::Dates.Instant)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:4
#   [10] +(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.UpperTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:642
#   [11] +(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.UnitUpperTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:644
#   [12] +(x::LinearAlgebra.UpperTriangular, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:112
#   [13] +(A::LinearAlgebra.UpperTriangular, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:91
#   [14] +(r1::StepRangeLen{T, R}, r2::StepRangeLen{T, R}) where {R<:Base.TwicePrecision, T}
#      @ twiceprecision.jl:628
#   [15] +(r1::StepRangeLen{T, S}, r2::StepRangeLen{T, S}) where {T, S}
#      @ range.jl:1464
#   [16] +(F::LinearAlgebra.Hessenberg, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:647
#   [17] +(y::AbstractFloat, x::Bool)
#      @ bool.jl:176
#   [18] +(Da::LinearAlgebra.Diagonal, Db::LinearAlgebra.Diagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:184
#   [19] +(D::LinearAlgebra.Diagonal, S::LinearAlgebra.Symmetric)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:188
#   [20] +(D::LinearAlgebra.Diagonal{var"#s972", V} where {var"#s972"<:Real, V<:AbstractVector{var"#s972"}}, H::LinearAlgebra.Hermitian)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:194
#   [21] +(x::LinearAlgebra.Diagonal, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:112
#   [22] +(A::LinearAlgebra.Diagonal, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:130
#   [23] +(A::LinearAlgebra.Diagonal, B::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:140
#   [24] +(A::LinearAlgebra.Diagonal, B::LinearAlgebra.Tridiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:168
#   [25] +(A::LinearAlgebra.Diagonal{var"#s972", V} where {var"#s972"<:Number, V<:AbstractVector{var"#s972"}}, B::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:246
#   [26] +(x::AbstractIrrational, y::AbstractIrrational)
#      @ irrationals.jl:161
#   [27] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.Tridiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/tridiag.jl:754
#   [28] +(x::LinearAlgebra.Tridiagonal, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:112
#   [29] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:162
#   [30] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.Diagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:178
#   [31] +(A::LinearAlgebra.Tridiagonal, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:198
#   [32] +(A::LinearAlgebra.Tridiagonal{var"#s972", V} where {var"#s972"<:Number, V<:AbstractVector{var"#s972"}}, B::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:231
#   [33] +(r1::OrdinalRange, r2::OrdinalRange)
#      @ range.jl:1441
#   [34] +(r1::LinRange{T}, r2::LinRange{T}) where T
#      @ range.jl:1448
#   [35] +(r1::Union{LinRange, OrdinalRange, StepRangeLen}, r2::Union{LinRange, OrdinalRange, StepRangeLen})
#      @ range.jl:1457
#   [36] +(x::T, y::Integer) where T<:AbstractChar
#      @ char.jl:237
#   [37] +(x::P, y::P) where P<:Dates.Period
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/periods.jl:75
#   [38] +(x::Dates.Period, y::Dates.Period)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/periods.jl:331
#   [39] +(y::Dates.Period, x::Dates.CompoundPeriod)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/periods.jl:333
#   [40] +(y::Dates.Period, x::Dates.TimeType)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:85
#   [41] +(x::Dates.Period, r::AbstractRange{<:Dates.TimeType})
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/ranges.jl:64
#   [42] +(y::Union{Dates.CompoundPeriod, Dates.Period}, x::AbstractArray{<:Dates.TimeType})
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/deprecated.jl:14
#   [43] +(A::LinearAlgebra.LowerTriangular, B::LinearAlgebra.LowerTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:643
#   [44] +(A::LinearAlgebra.LowerTriangular, B::LinearAlgebra.UnitLowerTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:645
#   [45] +(A::LinearAlgebra.LowerTriangular, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:91
#   [46] +(x::Base.TwicePrecision, y::Number)
#      @ twiceprecision.jl:290
#   [47] +(x::Base.TwicePrecision{T}, y::Base.TwicePrecision{T}) where T
#      @ twiceprecision.jl:296
#   [48] +(x::Base.TwicePrecision, y::Base.TwicePrecision)
#      @ twiceprecision.jl:301
#   [49] +(A::LinearAlgebra.UpperHessenberg, B::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:104
#   [50] +(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:111
#   [51] +(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.Diagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:111
#   [52] +(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:111
#   [53] +(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.Tridiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:111
#   [54] +(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:111
#   [55] +(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.UpperTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:111
#   [56] +(H::LinearAlgebra.UpperHessenberg, x::LinearAlgebra.UnitUpperTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:111
#   [57] +(A::SparseArrays.AbstractSparseMatrix, B::LinearAlgebra.Hermitian{<:Any, <:SparseArrays.AbstractSparseMatrix})
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:14
#   [58] +(A::SparseArrays.AbstractSparseMatrix, B::LinearAlgebra.Hermitian)
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:17
#   [59] +(A::SparseArrays.AbstractSparseMatrix, B::LinearAlgebra.Symmetric{<:Any, <:SparseArrays.AbstractSparseMatrix})
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:14
#   [60] +(A::SparseArrays.AbstractSparseMatrix, B::LinearAlgebra.Symmetric)
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:17
#   [61] +(J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:149
#   [62] +(J::LinearAlgebra.UniformScaling, x::Number)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:144
#   [63] +(J1::LinearAlgebra.UniformScaling, J2::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:150
#   [64] +(J::LinearAlgebra.UniformScaling, B::BitMatrix)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:152
#   [65] +(x::LinearAlgebra.UniformScaling, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:112
#   [66] +(J::LinearAlgebra.UniformScaling, F::LinearAlgebra.Hessenberg)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:648
#   [67] +(A::LinearAlgebra.UniformScaling, B::LinearAlgebra.Tridiagonal{var"#s972", V} where {var"#s972"<:Number, V<:AbstractVector{var"#s972"}})
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:250
#   [68] +(A::LinearAlgebra.UniformScaling, B::LinearAlgebra.SymTridiagonal{var"#s972", V} where {var"#s972"<:Number, V<:AbstractVector{var"#s972"}})
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:255
#   [69] +(A::LinearAlgebra.UniformScaling, B::LinearAlgebra.Bidiagonal{var"#s972", V} where {var"#s972"<:Number, V<:AbstractVector{var"#s972"}})
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:260
#   [70] +(A::LinearAlgebra.UniformScaling, B::LinearAlgebra.Diagonal{var"#s972", V} where {var"#s972"<:Number, V<:AbstractVector{var"#s972"}})
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:265
#   [71] +(J::LinearAlgebra.UniformScaling{T}, A::SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}) where {T<:Number, Tv, Ti}
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/sparsematrix.jl:4100
#   [72] +(J::LinearAlgebra.UniformScaling, A::AbstractMatrix)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:153
#   [73] +(A::LinearAlgebra.UnitUpperTriangular, B::LinearAlgebra.UpperTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:646
#   [74] +(A::LinearAlgebra.UnitUpperTriangular, B::LinearAlgebra.UnitUpperTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:648
#   [75] +(UL::LinearAlgebra.UnitUpperTriangular, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:181
#   [76] +(x::LinearAlgebra.UnitUpperTriangular, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:112
#   [77] +(A::LinearAlgebra.UnitUpperTriangular, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:91
#   [78] +(x::Ptr, y::Integer)
#      @ pointer.jl:167
#   [79] +(A::LinearAlgebra.UnitLowerTriangular, B::LinearAlgebra.LowerTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:647
#   [80] +(A::LinearAlgebra.UnitLowerTriangular, B::LinearAlgebra.UnitLowerTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:649
#   [81] +(A::LinearAlgebra.AbstractTriangular, B::LinearAlgebra.AbstractTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/triangular.jl:650
#   [82] +(UL::LinearAlgebra.UnitLowerTriangular, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:181
#   [83] +(A::LinearAlgebra.UnitLowerTriangular, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:91
#   [84] +(A::BitArray, B::BitArray)
#      @ bitarray.jl:1184
#   [85] +(A::SparseArrays.AbstractSparseMatrixCSC, B::SparseArrays.AbstractSparseMatrixCSC)
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/sparsematrix.jl:2065
#   [86] +(x::SparseArrays.AbstractSparseVector, y::SparseArrays.AbstractSparseVector)
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/sparsevector.jl:1516
#   [87] +(A::SparseArrays.AbstractSparseMatrixCSC, B::Array)
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/sparsematrix.jl:2068
#   [88] +(A::SparseArrays.AbstractSparseMatrixCSC{Tv, Ti}, J::LinearAlgebra.UniformScaling{T}) where {T<:Number, Tv, Ti}
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/sparsematrix.jl:4098
#   [89] +(y::Dates.TimeType, x::StridedArray{<:Union{Dates.CompoundPeriod, Dates.Period}})
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/deprecated.jl:18
#   [90] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/tridiag.jl:207
#   [91] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.Symmetric)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/symmetric.jl:485
#   [92] +(A::LinearAlgebra.SymTridiagonal{var"#s970", V} where {var"#s970"<:Real, V<:AbstractVector{var"#s970"}}, B::LinearAlgebra.Hermitian)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/symmetric.jl:487
#   [93] +(x::LinearAlgebra.SymTridiagonal, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:112
#   [94] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.Diagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:150
#   [95] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.Tridiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:164
#   [96] +(A::LinearAlgebra.SymTridiagonal, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:218
#   [97] +(A::LinearAlgebra.SymTridiagonal{var"#s972", V} where {var"#s972"<:Number, V<:AbstractVector{var"#s972"}}, B::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:236
#   [98] +(x::Rational, y::Integer)
#      @ rational.jl:327
#   [99] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.Bidiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/bidiag.jl:374
#  [100] +(x::LinearAlgebra.Bidiagonal, H::LinearAlgebra.UpperHessenberg)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/hessenberg.jl:112
#  [101] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.UpperTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:99
#  [102] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.UnitUpperTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:99
#  [103] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.LowerTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:99
#  [104] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.UnitLowerTriangular)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:99
#  [105] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.Diagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:120
#  [106] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.Tridiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:188
#  [107] +(A::LinearAlgebra.Bidiagonal, B::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:208
#  [108] +(A::LinearAlgebra.Bidiagonal{var"#s972", V} where {var"#s972"<:Number, V<:AbstractVector{var"#s972"}}, B::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/special.jl:241
#  [109] +(index1::CartesianIndex{N}, index2::CartesianIndex{N}) where N
#      @ Base.IteratorsMD multidimensional.jl:111
#  [110] +(A::LinearAlgebra.Hermitian, B::LinearAlgebra.Hermitian)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/symmetric.jl:469
#  [111] +(A::LinearAlgebra.Hermitian, B::LinearAlgebra.SymTridiagonal{var"#s969", V} where {var"#s969"<:Real, V<:AbstractVector{var"#s969"}})
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/symmetric.jl:488
#  [112] +(H::LinearAlgebra.Hermitian, D::LinearAlgebra.Diagonal{var"#s972", V} where {var"#s972"<:Real, V<:AbstractVector{var"#s972"}})
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:197
#  [113] +(A::LinearAlgebra.Hermitian, J::LinearAlgebra.UniformScaling{<:Complex})
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:195
#  [114] +(A::LinearAlgebra.Hermitian{<:Any, <:SparseArrays.AbstractSparseMatrix}, B::SparseArrays.AbstractSparseMatrix)
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:15
#  [115] +(A::LinearAlgebra.Hermitian, B::SparseArrays.AbstractSparseMatrix)
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:18
#  [116] +(A::LinearAlgebra.Hermitian{<:Any, <:SparseArrays.AbstractSparseMatrix}, B::LinearAlgebra.Symmetric{<:Real, <:SparseArrays.AbstractSparseMatrix})
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:26
#  [117] +(A::LinearAlgebra.Hermitian, B::LinearAlgebra.Symmetric{var"#s972", S} where {var"#s972"<:Real, S<:(AbstractMatrix{<:var"#s972"})})
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/symmetric.jl:483
#  [118] +(A::LinearAlgebra.Hermitian{<:Any, <:SparseArrays.AbstractSparseMatrix}, B::LinearAlgebra.Symmetric{<:Any, <:SparseArrays.AbstractSparseMatrix})
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:24
#  [119] +(z::Complex, w::Complex)
#      @ complex.jl:291
#  [120] +(r::AbstractRange{<:Dates.TimeType}, x::Dates.Period)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/ranges.jl:65
#  [121] +(x::AbstractArray{<:Dates.TimeType}, y::Union{Dates.CompoundPeriod, Dates.Period})
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/deprecated.jl:6
#  [122] +(A::Array, Bs::Array...)
#      @ arraymath.jl:12
#  [123] +(X::StridedArray{<:Union{Dates.CompoundPeriod, Dates.Period}}, Y::StridedArray{<:Union{Dates.CompoundPeriod, Dates.Period}})
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/deprecated.jl:62
#  [124] +(A::Array, B::SparseArrays.AbstractSparseMatrixCSC)
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/sparsematrix.jl:2069
#  [125] +(x::StridedArray{<:Union{Dates.CompoundPeriod, Dates.Period}})
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/deprecated.jl:55
#  [126] +(x::StridedArray{<:Union{Dates.CompoundPeriod, Dates.Period}}, y::Dates.TimeType)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/deprecated.jl:10
#  [127] +(A::LinearAlgebra.Symmetric, B::LinearAlgebra.Symmetric)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/symmetric.jl:469
#  [128] +(A::LinearAlgebra.Symmetric, B::LinearAlgebra.SymTridiagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/symmetric.jl:486
#  [129] +(S::LinearAlgebra.Symmetric, D::LinearAlgebra.Diagonal)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/diagonal.jl:191
#  [130] +(A::LinearAlgebra.Symmetric{<:Any, <:SparseArrays.AbstractSparseMatrix}, B::SparseArrays.AbstractSparseMatrix)
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:15
#  [131] +(A::LinearAlgebra.Symmetric, B::SparseArrays.AbstractSparseMatrix)
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:18
#  [132] +(A::LinearAlgebra.Symmetric{<:Real, <:SparseArrays.AbstractSparseMatrix}, B::LinearAlgebra.Hermitian{<:Any, <:SparseArrays.AbstractSparseMatrix})
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:25
#  [133] +(A::LinearAlgebra.Symmetric{var"#s971", S} where {var"#s971"<:Real, S<:(AbstractMatrix{<:var"#s971"})}, B::LinearAlgebra.Hermitian)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/symmetric.jl:484
#  [134] +(A::LinearAlgebra.Symmetric{<:Any, <:SparseArrays.AbstractSparseMatrix}, B::LinearAlgebra.Hermitian{<:Any, <:SparseArrays.AbstractSparseMatrix})
#      @ SparseArrays /usr/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:23
#  [135] +(A::AbstractArray, B::AbstractArray)
#      @ arraymath.jl:6
#  [136] +(dt::Dates.DateTime, y::Dates.Year)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:23
#  [137] +(dt::Dates.DateTime, z::Dates.Month)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:47
#  [138] +(x::Dates.DateTime, y::Dates.Quarter)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:75
#  [139] +(x::Dates.DateTime, y::Dates.Period)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:81
#  [140] +(x::Dates.Time, y::Dates.TimePeriod)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:83
#  [141] +(t::Dates.Time, dt::Dates.Date)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:20
#  [142] +(x::Rational{BigInt}, y::Rational{BigInt})
#      @ Base.GMP.MPQ gmp.jl:1027
#  [143] +(x::Rational)
#      @ rational.jl:284
#  [144] +(x::Rational, y::Rational)
#      @ rational.jl:298
#  [145] +(x::Bool)
#      @ bool.jl:163
#  [146] +(x::Integer, y::Ptr)
#      @ pointer.jl:169
#  [147] +(y::Integer, x::Rational)
#      @ rational.jl:334
#  [148] +(x::Integer, y::AbstractChar)
#      @ char.jl:247
#  [149] +(x::Bool, y::T) where T<:AbstractFloat
#      @ bool.jl:173
#  [150] +(x::Bool, y::Bool)
#      @ bool.jl:166
#  [151] +(x::Bool, z::Complex{Bool})
#      @ complex.jl:302
#  [152] +(x::Real, z::Complex{Bool})
#      @ complex.jl:316
#  [153] +(x::Bool, z::Complex)
#      @ complex.jl:309
#  [154] +(x::Real, z::Complex)
#      @ complex.jl:328
#  [155] +(B::BitMatrix, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:151
#  [156] +(A::AbstractMatrix, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:214
#  [157] +(x::AbstractArray{<:Number})
#      @ abstractarraymath.jl:220
#  [158] +(x::Dates.CompoundPeriod, y::Dates.Period)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/periods.jl:332
#  [159] +(x::Dates.CompoundPeriod, y::Dates.TimeType)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/periods.jl:362
#  [160] +(x::Dates.CompoundPeriod, y::Dates.CompoundPeriod)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/periods.jl:334
#  [161] +(z::Complex{Bool}, x::Bool)
#      @ complex.jl:303
#  [162] +(z::Complex, x::Bool)
#      @ complex.jl:310
#  [163] +(z::Complex{Bool}, x::Real)
#      @ complex.jl:317
#  [164] +(z::Complex)
#      @ complex.jl:289
#  [165] +(x::Number, y::Base.TwicePrecision)
#      @ twiceprecision.jl:294
#  [166] +(::Number, ::Missing)
#      @ missing.jl:124
#  [167] +(x::Number, J::LinearAlgebra.UniformScaling)
#      @ LinearAlgebra /usr/share/julia/stdlib/v1.9/LinearAlgebra/src/uniformscaling.jl:145
#  [168] +(z::Complex, x::Real)
#      @ complex.jl:329
#  [169] +(dt::Dates.Date, t::Dates.Time)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:19
#  [170] +(dt::Dates.Date, y::Dates.Year)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:27
#  [171] +(dt::Dates.Date, z::Dates.Month)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:54
#  [172] +(x::Dates.Date, y::Dates.Quarter)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:73
#  [173] +(x::Dates.Date, y::Dates.Week)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:77
#  [174] +(x::Dates.Date, y::Dates.Day)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:79
#  [175] +(x::Dates.TimeType)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:8
#  [176] +(x::Dates.AbstractTime, y::Missing)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:88
#  [177] +(a::Dates.TimeType, b::Dates.Period, c::Dates.Period)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/periods.jl:353
#  [178] +(a::Dates.TimeType, b::Dates.Period, c::Dates.Period, d::Dates.Period...)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/periods.jl:354
#  [179] +(x::Dates.TimeType, y::Dates.CompoundPeriod)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/periods.jl:356
#  [180] +(::Missing)
#      @ missing.jl:101
#  [181] +(::Missing, ::Number)
#      @ missing.jl:123
#  [182] +(x::Missing, y::Dates.AbstractTime)
#      @ Dates /usr/share/julia/stdlib/v1.9/Dates/src/arithmetic.jl:89
#  [183] +(::Missing, ::Missing)
#      @ missing.jl:122
#  [184] +(x::BigInt, c::Union{UInt16, UInt32, UInt64, UInt8})
#      @ Base.GMP gmp.jl:538
#  [185] +(x::BigInt, c::Union{Int16, Int32, Int64, Int8})
#      @ Base.GMP gmp.jl:544
#  [186] +(x::BigInt, y::BigInt)
#      @ Base.GMP gmp.jl:490
#  [187] +(a::BigInt, b::BigInt, c::BigInt)
#      @ Base.GMP gmp.jl:530
#  [188] +(a::BigInt, b::BigInt, c::BigInt, d::BigInt)
#      @ Base.GMP gmp.jl:531
#  [189] +(a::BigInt, b::BigInt, c::BigInt, d::BigInt, e::BigInt)
#      @ Base.GMP gmp.jl:532
#  [190] +(x::BigInt, y::BigInt, rest::BigInt...)
#      @ Base.GMP gmp.jl:666
#  [191] +(a::Integer, b::Integer)
#      @ int.jl:1038
#  [192] +(c::BigInt, x::BigFloat)
#      @ Base.MPFR mpfr.jl:431
#  [193] +(x::BigFloat, c::Union{UInt16, UInt32, UInt64, UInt8})
#      @ Base.MPFR mpfr.jl:402
#  [194] +(x::BigFloat, c::Union{Int16, Int32, Int64, Int8})
#      @ Base.MPFR mpfr.jl:410
#  [195] +(x::BigFloat, c::Union{Float16, Float32, Float64})
#      @ Base.MPFR mpfr.jl:418
#  [196] +(x::BigFloat, y::BigFloat)
#      @ Base.MPFR mpfr.jl:395
#  [197] +(x::BigFloat, c::BigInt)
#      @ Base.MPFR mpfr.jl:426
#  [198] +(a::BigFloat, b::BigFloat, c::BigFloat)
#      @ Base.MPFR mpfr.jl:567
#  [199] +(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat)
#      @ Base.MPFR mpfr.jl:573
#  [200] +(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat, e::BigFloat)
#      @ Base.MPFR mpfr.jl:580
#  [201] +(x::Number)
#      @ operators.jl:515
#  [202] +(x::T, y::T) where T<:Number
#      @ promotion.jl:485
#  [203] +(x::Number, y::Number)
#      @ promotion.jl:410
#  [204] +(level::Base.CoreLogging.LogLevel, inc::Integer)
#      @ Base.CoreLogging logging.jl:131
#  [205] +(a::Pkg.Resolve.FieldValue, b::Pkg.Resolve.FieldValue)
#      @ Pkg.Resolve /usr/share/julia/stdlib/v1.9/Pkg/src/Resolve/fieldvalues.jl:43
#  [206] +(a::Pkg.Resolve.VersionWeight, b::Pkg.Resolve.VersionWeight)
#      @ Pkg.Resolve /usr/share/julia/stdlib/v1.9/Pkg/src/Resolve/versionweights.jl:22
#  [207] +(a, b, c, xs...)
#      @ operators.jl:578

# %%
f(x::Float64, y::Float64) = 2x + y
# Out:
# f (generic function with 1 method)

# %%
f(2.0, 3.0)
# Out:
# 7.0

# %%
f(2.0, 3)
# Out:
# MethodError: no method matching f(::Float64, ::Int64)
#
# Closest candidates are:
#   f(::Float64, ::Float64)
#    @ Main In[4]:1
#
#
# Stacktrace:
#  [1] top-level scope
#    @ In[6]:1

# %%
f(x::Number, y::Number) = 2x - y
# Out:
# f (generic function with 2 methods)

# %%
f(2.0, 3)
# Out:
# 1.0

# %%
methods(f)
# Out:
# # 2 methods for generic function "f" from Main:
#  [1] f(x::Float64, y::Float64)
#      @ In[4]:1
#  [2] f(x::Number, y::Number)
#      @ In[7]:1

# %% [markdown]
# # Update as of January 2022
#
# After a long time I revisited "my" notebook server and found IJulia not working any longer (don't know why, may be an update of Julia environment)
#
# ```
#     [I 20:24:49.362 NotebookApp] Kernel started: 80c94540-a495-4416-bf92-f5460e177e18, name: julia-1.5
#     ERROR: LoadError: ArgumentError: Package IJulia not found in current path:
#     - Run `import Pkg; Pkg.add("IJulia")` to install the IJulia package.
#     ...
# ```
#
#
# Right, package IJulia is not in environment
#
# ```
#     julia -e 'using Pkg; Pkg.status()'
#         Status `~/.julia/environments/v1.7/Project.toml` (empty project)
# ```
#
#
# So let's reinstall it, IJulia for Julia has as many dependencies as EvCxR has for Rust.
#
# ```
#     julia -e 'using Pkg; Pkg.add("IJulia")'
#         Updating registry at `~/.julia/registries/General`
#       Resolving package versions...
#       Installed Conda ────────── v1.6.0
#       Installed ZeroMQ_jll ───── v4.3.4+0
#       Installed VersionParsing ─ v1.3.0
#       Installed Preferences ──── v1.2.3
#       Installed Parsers ──────── v2.2.0
#       Installed JSON ─────────── v0.21.2
#       Installed IJulia ───────── v1.23.2
#       Installed JLLWrappers ──── v1.4.0
#       Installed libsodium_jll ── v1.0.20+0
#       Downloaded artifact: ZeroMQ
#       Downloaded artifact: libsodium
#         Updating `~/.julia/environments/v1.7/Project.toml`
#       [7073ff75] + IJulia v1.23.2
#         Updating `~/.julia/environments/v1.7/Manifest.toml`
#       [8f4d0f93] + Conda v1.6.0
#       [7073ff75] + IJulia v1.23.2
#       [692b3bcd] + JLLWrappers v1.4.0
#       [682c06a0] + JSON v0.21.2
#       [739be429] + MbedTLS v1.0.3
#       [69de0a69] + Parsers v2.2.0
#       [21216c6a] + Preferences v1.2.3
#       [b85f4697] + SoftGlobalScope v1.1.0
#       [81def892] + VersionParsing v1.3.0
#       [c2297ded] + ZMQ v1.2.1
#       [8f1865be] + ZeroMQ_jll v4.3.4+0
#       [a9144af2] + libsodium_jll v1.0.20+0
#       [0dad84c5] + ArgTools
#       [56f22d72] + Artifacts
#       [2a0f44e3] + Base64
#       [ade2ca70] + Dates
#       [f43a241f] + Downloads
#       [b27032c2] + LibCURL
#       [76f85450] + LibGit2
#       [8f399da3] + Libdl
#       [56ddb016] + Logging
#       [d6f4376e] + Markdown
#       [a63ad114] + Mmap
#       [ca575930] + NetworkOptions
#       [44cfe95a] + Pkg
#       [de0858da] + Printf
#       [3fa0cd96] + REPL
#       [9a3f8284] + Random
#       [ea8e919c] + SHA
#       [9e88b42a] + Serialization
#       [6462fe0b] + Sockets
#       [fa267f1f] + TOML
#       [a4e569a6] + Tar
#       [8dfed614] + Test
#       [cf7118a7] + UUIDs
#       [4ec0a83e] + Unicode
#       [deac9b47] + LibCURL_jll
#       [29816b5a] + LibSSH2_jll
#       [c8ffd9c3] + MbedTLS_jll
#       [14a3606d] + MozillaCACerts_jll
#       [83775a58] + Zlib_jll
#       [8e850ede] + nghttp2_jll
#       [3f19e933] + p7zip_jll
#         Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/6cdc8832ba11c7695f494c9d9a1c31e90959ce0f/build.log`
#         Building IJulia → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/d8b9c31196e1dd92181cd0f5760ca2d2ffb4ac0f/build.log`
#     Precompiling project...
#       11 dependencies successfully precompiled in 4 seconds (4 already precompiled)
#
#     julia -e 'using Pkg; Pkg.status()'
#           Status `~/.julia/environments/v1.7/Project.toml`
#       [7073ff75] IJulia v1.23.2
# ```

# %% [markdown]
# # Update as of December 2023
#
# Same procedure as every year ... after a long time I revisited "my" notebook server and found IJulia not working any longer, the system has updated Julia to version 1.9.
#
# ```
# [tilo@holm play-jupyter]$ julia -e 'using Pkg; Pkg.status()'
# Status `~/.julia/environments/v1.9/Project.toml`
#   [7073ff75] IJulia v1.24.2
# [tilo@holm play-jupyter]$
# ```
